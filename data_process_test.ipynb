# %% [markdown]
# a experiemnt

# %%
from add_mask import add_suffix

# %%
add_suffix()
# Out:
# ./dataset/all_tumors_reg/BraTS19_TMC_15477_1_seg_reg_mask.nii.gz
# ./dataset/all_tumors_reg/BraTS19_TCIA08_162_1_seg_reg_mask.nii.gz
# ./dataset/all_tumors_reg/BraTS19_TCIA08_218_1_seg_reg_mask.nii.gz
# ./dataset/all_tumors_reg/BraTS19_TCIA12_480_1_seg_reg_mask.nii.gz
# ./dataset/all_tumors_reg/BraTS19_CBICA_BAX_1_seg_reg_mask.nii.gz
# ./dataset/all_tumors_reg/BraTS19_2013_12_1_seg_reg_mask.nii.gz
# ./dataset/all_tumors_reg/BraTS19_TCIA10_103_1_seg_reg_mask.nii.gz
# ./dataset/all_tumors_reg/BraTS19_2013_3_1_seg_reg_mask.nii.gz
# ./dataset/all_tumors_reg/BraTS19_TCIA06_603_1_seg_reg_mask.nii.gz
# ./dataset/all_tumors_reg/BraTS19_TCIA02_300_1_seg_reg_mask.nii.gz
# ./dataset/all_tumors_reg/BraTS19_TCIA10_175_1_seg_reg_mask.nii.gz
# ./dataset/all_tumors_reg/BraTS19_TCIA12_470_1_seg_reg_mask.nii.gz
# ./dataset/all_tumors_reg/BraTS19_TCIA02_608_1_seg_reg_mask.nii.gz
# ./dataset/all_tumors_reg/BraTS19_CBICA_AQO_1_seg_reg_mask.nii.gz
# ...

# %%
add_suffix()
# Out:
# the data names have already been modified, no further action will be taken
